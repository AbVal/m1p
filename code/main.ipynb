# %% [markdown]
# # Установка нужных библиотек

# %%
import warnings
warnings.filterwarnings("ignore")
from cali_housing import run_basic_experiment, run_noise_experiment
from visualize_principle import visualize_basic, visualize_noisy

# %% [markdown]
# # Эксперименты с RandomForestRegressor

# %% [markdown]
# ## Базовый DEHB

# %%
df, ax = run_basic_experiment(fig_name='basic_experiment.pdf', fig_title='Зависимость ошибки на валидации от количества итераций DEHB', runs=10, fevals=100)
# Out:
# Dimensionality of search space: 4
# Cali Housing
# Train size: (1400, 8)
# Valid size: (400, 8)
# Test size: (200, 8)
# 2023-10-27 05:33:14.059 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:14 MSK
#
#
# 2023-10-27 05:33:20.546 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:20 MSK
#
#
# 2023-10-27 05:33:27.181 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:27 MSK
#
#
# 2023-10-27 05:33:35.794 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:35 MSK
#
#
# 2023-10-27 05:33:41.786 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:41 MSK
#
#
# 2023-10-27 05:33:47.734 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:47 MSK
#
#
# 2023-10-27 05:33:55.241 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:33:55 MSK
#
#
# 2023-10-27 05:34:02.408 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# ...

# %% [markdown]
# ## Сравнение базового DEHB и DEHB с зашумленной мутацией

# %%
df1, df2, ax = run_noise_experiment(fig_name='noisy_experiment.pdf', fig_title='Зависимость ошибки на валидации от количества итераций DEHB', runs=10, fevals=75)
# Out:
# Dimensionality of search space: 4
# Cali Housing
# Train size: (1400, 8)
# Valid size: (400, 8)
# Test size: (200, 8)
# 2023-10-27 05:35:12.379 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:12 MSK
#
#
# 2023-10-27 05:35:18.214 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:18 MSK
#
#
# 2023-10-27 05:35:24.702 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:24 MSK
#
#
# 2023-10-27 05:35:30.484 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:30 MSK
#
#
# 2023-10-27 05:35:37.623 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:37 MSK
#
#
# 2023-10-27 05:35:44.300 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:44 MSK
#
#
# 2023-10-27 05:35:51.244 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# RESET at 10/27/23 05:35:51 MSK
#
#
# 2023-10-27 05:35:57.671 | INFO     | dehb.optimizers.dehb:reset:121 -
#
# ...

# %% [markdown]
# # Визуализация принципа

# %%
visualize_basic()

# %%
visualize_noisy()
